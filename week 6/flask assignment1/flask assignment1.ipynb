# %%
##ques 1

# %% [markdown]
# Flask is a micro web farmework which is used to design web applications .
# It provides only the essential components required to handle web request and response.
#
# ADVANTAGES:
#
# 1.Lightweight- It is simple and light weight. It doesn't come with built in features
#
# 2. Flexibility- It provides flexibility to user to choose the componenet according to
# their need and to structure their application according to prefernce
#
# 3. Extensible- We can extend the functionality of Flask by integrating it with libraries
# and database

# %%
##ques 2

# %% [markdown]
# ![image.png](attachment:8859852b-e666-438a-9b96-153c34565799.png)

# %% [markdown]
# ![image.png](attachment:875dcfbe-b609-4954-964c-72e1514a19e4.png)

# %% [markdown]
# ##ques 3
#
# In Flsk, App routing refers to process of mapping URL with specfic functions,modules
# of python language. It is used to determine the URL entered by user is handled by which function and w
# what response has to be provided.
#
# PURPOSE OF APP ROUTING:
#
# 1. URL MAPPING- To map URL with different functions of python
#
# 2.code separation- To segregate different logic for different parts of website into sepate function.
#
# 3. It provdes modularity

# %%
##ques 4

# %% [markdown]
# ![image.png](attachment:f0f9b260-2862-40d6-b306-5f075e67d220.png)

# %% [markdown]
# ![image.png](attachment:748c0509-e641-45f6-b96c-d04707db630a.png)

# %% [markdown]
# ![image.png](attachment:4c9bcbc5-25c3-43e6-b97d-42b97416830c.png)

# %%
##ques5

url_for() is used for making url and to include as a link in response content

# %% [markdown]
# ![image.png](attachment:d4a8d4b5-7438-4982-9f63-cd4237a15fde.png)

# %% [markdown]
# ![image.png](attachment:3655173c-cf64-47a0-aa5b-0c8259de252f.png)
