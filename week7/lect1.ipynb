# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url="https://www.flipkart.com/search?q="+"iphone12"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12'

# %%
urlclient=uReq(flipcart_url)

# %%
flipcart_page=urlclient.read()

# %%
flipcart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.d4bb4f.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipcart_html=bs(flipcart_page,'html.parser')  ##to beautify it a little bit so it can be readble

# %%
"https://www.flipkart.com/"+"apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=870bf2bc-d35f-4c3c-923a-14ebe5f1fb45.MOBFWQ6BVWVEH3XE.SEARCH&ppt=hp&ppn=homepage&ssid=57ac2aeoqo0000001693191274604&qH=f6cdfdaa9f3c23f3"
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=870bf2bc-d35f-4c3c-923a-14ebe5f1fb45.MOBFWQ6BVWVEH3XE.SEARCH&ppt=hp&ppn=homepage&ssid=57ac2aeoqo0000001693191274604&qH=f6cdfdaa9f3c23f3'

# %%
bigbox= flipcart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 31

# %%
del bigbox[0:3]

# %%
productlink="https://www.flipkart.com"+bigbox[4].div.div.div.a['href']

# %%
product_req=requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-12-purple-64-gb/p/itmfca1e77621c65?pid=MOBG2EPZJUZEYZGK&lid=LSTMOBG2EPZJUZEYZGK3JC9XU&marketplace=FLIPKART&q=iphone12&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=27165f24-6965-4acf-aa3f-5ad773d7d913.MOBG2EPZJUZEYZGK.SEARCH&ppt=None&ppn=None&ssid=oyaj5p83r40000001693191638983&qH=ad588135f239b88b'

# %%
product_html=bs(product_req.text,'html.parser')

# %%
comment_box=product_html.find_all('div',{'class':"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.find_all('p',{'class':"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Hariprasad b'

# %%
for i in comment_box:
    print(i.div.find_all('p',{'class':"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Hariprasad b
# Sibsankar Das
# Sivaramaraju Raju
# Rupesh Thik
# Jaya chandra  Reddy
# Arjun  Chakravarti
# Manoj Kumar
# Shivam Kengale
# Ankur Sharma
# Sunita  Yadav
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.find_all('p',{'class':"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Wonderful'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Wonderful
# Must buy!
# Must buy!
# Simply awesome
# Simply awesome
# Classy product
# Worth every penny
# Must buy!
# Very Good
# Classy product
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.find_all('div',{'class':''})[0].text
# Out:
# 'Performance is soooo fastEspecially faceid detection is awesome even in darkNo need to carry an dslr .this is more than enough attaching puc taken by thisREAD MORE'

# %%
for i in comment_box:
    print(i.div.find_all('div',{'class':''})[0].text)
# Out:
# Performance is soooo fastEspecially faceid detection is awesome even in darkNo need to carry an dslr .this is more than enough attaching puc taken by thisREAD MORE
# Camera quality is just fabulous. Interface is very smooth.  Good for photography and videography.READ MORE
# Best iPhone till date 💕READ MORE
# Awesome CameraREAD MORE
# Amazing phone  In love with this phoneREAD MORE
# AwesomeREAD MORE
# SuperREAD MORE
# Go for itREAD MORE
# display is good , processor is awesomeREAD MORE
# This is the value for money phone. For Flipkart:On time delieveryAlways best serviceFeedback call received after 5 daysApple:One word: SuperbPicture Quality UltimateREAD MORE
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.find_all('div',{'class':''})[0].text)
#
# ...

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-12-blue-64-gb/p/itm5778ad0d0d255?pid=MOBFWBYZ8DNJNY7N&lid=LSTMOBFWBYZ8DNJNY7NK9PX3E&marketplace=FLIPKART&q=iphone12&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=27165f24-6965-4acf-aa3f-5ad773d7d913.MOBFWBYZ8DNJNY7N.SEARCH&ppt=None&ppn=None&ssid=oyaj5p83r40000001693191638983&qH=ad588135f239b88b
# https://www.flipkart.com/apple-iphone-12-green-64-gb/p/itmc8a19a9686173?pid=MOBFWBYZKK3EJPFW&lid=LSTMOBFWBYZKK3EJPFWVBZVKG&marketplace=FLIPKART&q=iphone12&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=27165f24-6965-4acf-aa3f-5ad773d7d913.MOBFWBYZKK3EJPFW.SEARCH&ppt=None&ppn=None&ssid=oyaj5p83r40000001693191638983&qH=ad588135f239b88b
# ...
