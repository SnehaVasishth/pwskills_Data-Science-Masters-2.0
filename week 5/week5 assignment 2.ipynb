# %% [markdown]
# ##ques 1
#
# Exception is the base class which consists of all exception related to pyhton language related problems and custom exception helps to design our own exception which is specific to the project. Thus by inheriting exception base classs we can ensure about both eceptions which ,may arise due to project specific problem and due to python related problem

# %%
##ques2

import inspect  ##help to get knowledge about class, method nd function
def printing(ex, i=0):
    print('#' * i,ex.__name__)
    
    for t in ex.__subclasses__():
        printing(t,i+3)
        
inspect.getclasstree(inspect.getmro(BaseException))
printing(BaseException)
# Out:
#  BaseException
# ### Exception
# ###### TypeError
# ######### FloatOperation
# ######### MultipartConversionError
# ###### StopAsyncIteration
# ###### StopIteration
# ###### ImportError
# ######### ModuleNotFoundError
# ######### ZipImportError
# ###### OSError
# ######### ConnectionError
# ############ BrokenPipeError
# ############ ConnectionAbortedError
# ############ ConnectionRefusedError
# ############ ConnectionResetError
# ############### RemoteDisconnected
# ######### BlockingIOError
# ######### ChildProcessError
# ######### FileExistsError
# ######### FileNotFoundError
# ######### IsADirectoryError
# ######### NotADirectoryError
# ######### InterruptedError
# ############ InterruptedSystemCall
# ######### PermissionError
# ######### ProcessLookupError
# ######### TimeoutError
# ######### UnsupportedOperation
# ######### itimer_error
# ######### herror
# ######### gaierror
# ######### SSLError
# ############ SSLCertVerificationError
# ############ SSLZeroReturnError
# ...

# %% [markdown]
# ##ques 3
#
# Following are the errors defined inside Arithematic error class:
#
# 1. ZeroDivisionError
# 2. OverFlowError
# 3. FloatingPointError
# 4. TimeOutError
# 5. ValueError

# %%
##ques 3


try:
    a=10
    c=10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a=int("sneha")
except ValueError as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'sneha'

# %% [markdown]
# ##ques 4
#  lookup errors used for exceptions related to dictionary and sequence related
# following are the errors defined insdide LookupError class:
#     1. IndexError
#     2. KeyError
#     3. ModuleNotFoundError

# %%
##ques 4


dic={'1': "sneha", '2':"Vasishth", '3':"Khushi"}
try:
    v=dic['5']
except KeyError as e:
    print(e)
# Out:
# '5'

# %%
l=[1,2,3,4]
try:
    print(l[5])   
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# ##ques 5
#
# Import error happens when there is a problem in importing suitable modules. Such error encounters when there is ciruclar importing of modules.
#
# ModuleNotFoundError is present inside LookupError superclass. This exception is use when we are not sure such module even exist in python or not

# %% [markdown]
# ##ques 6
#
# Best Practises are as follows
#
# 1. Instead of using 'print' use logging to log all the erros and exception which encounters in the project
#
# 2. always try to log good and understandable messge so that user may understand what kind of error may appear
#
# 3. Do not write multiple exception. If exact exception may not known use 'Exception' superclass it willl handle all python in-built exceptions
